# %%
import os
import json
import glob

# %%
conn = psycopg2.connect(host="localhost",dbname="testdb",user="postgres",password="admin")
conn.autocommit = True
cur = conn.cursor()

# %%
open((os.getcwd()+"data"),"w")
print(os.getcwd()+"data")
# Out:
# C:\Users\Sachi\data-modeling-with-postgres-masterdata

# %%
import pandas as pd

# %%
import psycopg2

# %%
dataframe = pd.read_json(r'C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A\A\A\TRAAAAW128F429D538.json',lines = True)
print(dataframe)
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARD7TVE1187B99BFB1              NaN               NaN
#
#    artist_location artist_name             song_id             title  \
# 0  California - LA      Casual  SOMZWCG12A8C13C480  I Didn't Mean To
#
#     duration  year
# 0  218.93179     0

# %%
songdata=pd.DataFrame(dataframe)

# %%
valu =songdata.values[0]

# %%
print(valu)
# Out:
# [1 'ARD7TVE1187B99BFB1' nan nan 'California - LA' 'Casual'
#  'SOMZWCG12A8C13C480' "I Didn't Mean To" 218.93179 0]

# %%
dataframe.to_json()
# Out:
# '{"0":{"num_songs":1,"artist_id":"ARD7TVE1187B99BFB1","artist_latitude":null,"artist_longitude":null,"artist_location":"California - LA","artist_name":"Casual","song_id":"SOMZWCG12A8C13C480","title":"I Didn\'t Mean To","duration":218.93179,"year":0}}'

# %%
df = pd.read_json(r'C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11\2018-11-01-events.json',lines = True)
print(df)
# Out:
#                         artist       auth firstName gender  itemInSession  \
# 0                         None  Logged In    Walter      M              0
# 1                         None  Logged In    Kaylee      F              0
# 2                      Des'ree  Logged In    Kaylee      F              1
# 3                         None  Logged In    Kaylee      F              2
# 4                      Mr Oizo  Logged In    Kaylee      F              3
# 5                   Tamba Trio  Logged In    Kaylee      F              4
# 6               The Mars Volta  Logged In    Kaylee      F              5
# 7            Infected Mushroom  Logged In    Kaylee      F              6
# 8   Blue October / Imogen Heap  Logged In    Kaylee      F              7
# 9                    Girl Talk  Logged In    Kaylee      F              8
# 10             Black Eyed Peas  Logged In    Sylvie      F              0
# 11                        None  Logged In      Ryan      M              0
# ...

# %%
query = """CREATE TABLE song_data(num_songs int,artists_id varchar(256),artist_latitude varchar,artist_longitude varchar,artist_location varchar,artist_name varchar, song_id varchar primary key,title varchar(256),duration float,year int)"""
cur.execute(query)

# %%
query2 = """INSERT INTO song_data(num_songs,artists_id,artist_latitude,artist_longitude,artist_location,artist_name,song_id,title,duration,year) VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
cur.execute(query2,valu)

# %%
for i, row in df.iterrows():
    print(1)
    print(row)
# Out:
# 1
# artist                                                        None
# auth                                                     Logged In
# firstName                                                   Walter
# gender                                                           M
# itemInSession                                                    0
# lastName                                                      Frye
# length                                                         NaN
# level                                                         free
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         GET
# page                                                          Home
# registration                                         1540919166796
# sessionId                                                       38
# song                                                          None
# ...

# %%
query = """CREATE TABLE song_data(num_songs int,artists_id varchar(256),artist_latitude varchar,artist_longitude varchar,artist_location varchar,artist_name varchar, song_id varchar primary key,title varchar(256),duration float,year int)"""
cur.execute(query)

# %%
df['ts'] = pd.to_datetime(df['ts'], unit='ms')
t = df.copy()
t.head()
# Out:
#     artist       auth firstName gender  itemInSession lastName     length  \
# 0     None  Logged In    Walter      M              0     Frye        NaN
# 1     None  Logged In    Kaylee      F              0  Summers        NaN
# 2  Des'ree  Logged In    Kaylee      F              1  Summers  246.30812
# 3     None  Logged In    Kaylee      F              2  Summers        NaN
# 4  Mr Oizo  Logged In    Kaylee      F              3  Summers  144.03873
#
#   level                           location method      page   registration  \
# 0  free  San Francisco-Oakland-Hayward, CA    GET      Home  1540919166796
# 1  free        Phoenix-Mesa-Scottsdale, AZ    GET      Home  1540344794796
# 2  free        Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong  1540344794796
# 3  free        Phoenix-Mesa-Scottsdale, AZ    GET   Upgrade  1540344794796
# 4  free        Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong  1540344794796
#
#    sessionId          song  status                      ts  \
# ...

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %%
import glob
song_files = get_files(r"C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data")
print(song_files)
# Out:
# ['C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\song_data\\A\\A\\A\\TRAAAAW128F429D538.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\song_data\\A\\A\\A\\TRAAABD128F429CF47.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\song_data\\A\\A\\A\\TRAAADZ128F9348C2E.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\song_data\\A\\A\\A\\TRAAAEF128F4273421.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\song_data\\A\\A\\A\\TRAAAFD128F92F423A.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\song_data\\A\\A\\A\\TRAAAMO128F1481E7F.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\song_data\\A\\A\\A\\TRAAAMQ128F1460CD3.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\song_data\\A\\A\\A\\TRAAAPK128E0786D96.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\song_data\\A\\A\\A\\TRAAARJ128F9320760.json', 'C:\\Users\\Sachi\\data-modeling-w
# ...

# %%
song_files = get_files(r"C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data")
for path in song_files:
    new_df = pd.read_json(path,lines = True)
    print(pd.DataFrame(new_df))
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARD7TVE1187B99BFB1              NaN               NaN
#
#    artist_location artist_name             song_id             title  \
# 0  California - LA      Casual  SOMZWCG12A8C13C480  I Didn't Mean To
#
#     duration  year
# 0  218.93179     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARMJAGH1187FB546F3         35.14968         -90.04892
#
#   artist_location   artist_name             song_id      title   duration  \
# 0     Memphis, TN  The Box Tops  SOCIWDW12A8C13D406  Soul Deep  148.03546
#
#    year
# 0  1969
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARKRRTF1187B9984DA              NaN               NaN
#
#   artist_location       artist_name             song_id            title  \
# 0                  Sonora Santanera  SOXVLOJ12AB0189215  Amor De Cabaret
#
#     duration  year
# 0  177.47546     0
# ...

# %%
import json 
import glob
import pandas as pd
import psycopg2

# OUR DESIGNED DB
# SONG_DATA:
#     {
#      "song_id": "SOMZWCG12A8C13C480", 
#      "title": "I Didn't Mean To", 
#      "duration": 218.93179,
#      "year": 0,
#      "artist_id": "ARD7TVE1187B99BFB1"   
#     }

# USER_DATA:
#     {
#     "userId":"39",
#     "firstname":"Walter",
#     "lastname":"Frye",
#     "location":"san francisco_oakland-hayward",
#     "gender":"M"
#     }

# ARTIST_DATA:
#     {
#     "artist_id": "ARD7TVE1187B99BFB1",
#     "artist_name": "casual",
#     "artist_latitude": null, 
#     "artist_longitude": null, 
#     "artist_location": "California - LA"
#     }

# SONG_PLAYED:
#     {
#     "sessionId":38,
#     "userId":"39",
#     "level":"free",
#     "song_id": "SOMZWCG12A8C13C480",
#     "location":"San Francisco-Oakland-Hayward,CA"
#     "userAgent":"\"Mozilla\/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit\/537.36 (KHTML, like Gecko) Chrome\/36.0.1985.143 Safari\/537.36\"",
#     "page":"Home",
#     "ts":1541105830796,
#     "song_play_id": seriel number
#     }

# SESSION_TIME:
#     {
#     'start_time',
#     'hour',
#     'day',
#     'week',
#     'month',
#     'year',
#     'weekday'
#     }

# FUNCTION TO GET PATH OF ALL FILES IN log_data FOLDER

def ALL_JSON1:
    jsons=[]
    path = r'C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11'
    files = os.scandir(path)
    for file in files:
        jsons.append(path+"\\"+file.name)
    return jsons

# FUNCTION TO GET PATH OF ALL FILES IN song_data FOLDER

def ALL_JSON2:
    jsons=[]
    other_dir = ['\\A','\\B','\\C']
    for dirs in other_dir[0:1]:
        path = r'C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A'
        path1 = path+dirs
        for dirs2 in other_dir:
            path2 = path1+dirs2
            files = os.scandir(path2)
            for file in files:
                jsons.append(path+"\\"+file.name)
    return jsons

# FIRST ESTABLISHING CONNECTION TO POSTGRESQL WITH psycopg2
conn = psycopg2.connect(host="localhost",dbname="testdb",user="postgres",password="admin")
conn.autocommit = True
cur = conn.cursor()

# CREATING TABLES IN POSTGRESQL

for query in CREATE_QUERIES:
    cur.execute(query)
    print(query+'is executed successfully')

# %%
import os

path = r'C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11'
files = os.listdir(path)
for file in files:
    print(path+"\\"+file)
# Out:
# C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11\2018-11-01-events.json
# C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11\2018-11-02-events.json
# C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11\2018-11-03-events.json
# C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11\2018-11-04-events.json
# C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11\2018-11-05-events.json
# C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11\2018-11-06-events.json
# C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11\2018-11-07-events.json
# C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11\2018-11-08-events.json
# C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11\2018-11-09-events.json
# C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11\2018-11-10-events.json
# ...

# %%
jsons=[]
path = r'C:\Users\Sachi\data-modeling-with-postgres-master\data\log_data\2018\11'
files = os.scandir(path)
# print(files)
for file in files:
#     print(file.name)
    jsons.append(path+'\\'+file.name)
print(jsons)
for path in jsons:
    df=pd.read_json(path,lines=True)
    print(df)
# Out:
# ['C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\log_data\\2018\\11\\2018-11-01-events.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\log_data\\2018\\11\\2018-11-02-events.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\log_data\\2018\\11\\2018-11-03-events.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\log_data\\2018\\11\\2018-11-04-events.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\log_data\\2018\\11\\2018-11-05-events.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\log_data\\2018\\11\\2018-11-06-events.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\log_data\\2018\\11\\2018-11-07-events.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\log_data\\2018\\11\\2018-11-08-events.json', 'C:\\Users\\Sachi\\data-modeling-with-postgres-master\\data\\log_data\\2018\\11\\2018-11-09-events.json', 'C:\\Users\\Sachi\\data-modeling-with-postg
# ...

# %%
jsons.clear()

# %%
jsons=[]
other_dir = ['\\A','\\B','\\C']
for dirs in other_dir[0:2]:
    print(dirs)
    path = r'C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A'
    path1 = path+dirs
    for dirs2 in other_dir:
        path2 = path1+dirs2
        print(path2)
        files = os.scandir(path)
        for file in files:
            jsons.append(path+"\\"+file.name)
print(jsons)
# Out:
# \A
# C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A\A\A
# C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A\A\B
# C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A\A\C
# \B
# C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A\B\A
# C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A\B\B
# C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A\B\C
# ...

# %%
from sql_queries import *

# %%
for query in CREATE_QUERIES:
    cur.execute(query)
    print(query+'........IS EXECUTED SUCCESSFULLY')
# Out:
# CREATE TABLE USER_DATA(user_id int PRIMARY KEY NOT NULL, firstname varchar, lastname varchar, gender varchar,level varchar)is executed successfully
# CREATE TABLE SONG_DATA(song_id varchar PRIMARY KEY NOT NULL, title varchar, duration float, year int, artist_id varchar)is executed successfully
# CREATE TABLE SESSION_TIME(start_time timestamp PRIMARY KEY, hour int NOT NULL, day int NOT NULL, week int NOT NULL, month int NOT NULL, year int NOT NULL, weekday int NOT NULL)is executed successfully
# CREATE TABLE SONG_PLAYED(song_play_id serial PRIMARY KEY NOT NULL, user_id int, level varchar, song_id varchar, location varchar, useragent varchar, page varchar,session_id int)is executed successfully
# CREATE TABLE ARTIST_DATA(artist_id varchar PRIMARY KEY NOT NULL, artist_name varchar, artist_latitude varchar, artist_longitude varchar, artist_location varchar)is executed successfully

# %%
import glob
path = r"C:\Users\Sachi\data-modeling-with-postgres-master\data"

all_files = glob.glob(r"C:\Users\Sachi\data-modeling-with-postgres-master\data*.json")
print(all_files)
# Out:
# []

# %%
print(os.path.abspath(r"song_data"))
# Out:
# C:\Users\Sachi\data-modeling-with-postgres-master\song_data

# %%
import numpy

# %%
def get_all_json_files_path(path):
    json_files =[]
    for root,folders,files in os.walk(path):
        temp_paths = glob.glob(os.path.join(root,"*.json"))
        for f in temp_paths:
            json_files.append(os.path.abspath(f))
    return json_files

# path = r'C:\Users\Sachi\data-modeling-with-postgres-master\log_data'

# log_files_path = get_all_json_files_path(os.path.abspath(r"C:\Users\Sachi\data-modeling-with-postgres-master\log_data"))
# log_df=(pd.read_json(f,lines=True) for f in log_files_path)
# # log_df.reset_index(drop=True,inplace=True)
# print(log_df)

# %%
def addapt_numpy_float64(numpy_float64):
    return AsIs(numpy_float64)
def addapt_numpy_int64(numpy_int64):
    return AsIs(numpy_int64)
def addapt_numpy_int32(numpy_int32):
    return AsIs(numpy_int32)

# %%
import numpy
from psycopg2.extensions import register_adapter, AsIs

register_adapter(numpy.float64, addapt_numpy_float64)
register_adapter(numpy.int64, addapt_numpy_int64)
register_adapter(numpy.float64, addapt_numpy_int32)

# %%
log_files = get_all_json_files_path(os.path.abspath("data/log_data/"))
for file in log_files:
    df = pd.read_json(file,lines = True)
#     user_data = df[["user_id","firstname","lastname","gender","level"]].values.tolist()
    print(df)
# Out:
#                         artist       auth firstName gender  itemInSession  \
# 0                         None  Logged In    Walter      M              0
# 1                         None  Logged In    Kaylee      F              0
# 2                      Des'ree  Logged In    Kaylee      F              1
# 3                         None  Logged In    Kaylee      F              2
# 4                      Mr Oizo  Logged In    Kaylee      F              3
# 5                   Tamba Trio  Logged In    Kaylee      F              4
# 6               The Mars Volta  Logged In    Kaylee      F              5
# 7            Infected Mushroom  Logged In    Kaylee      F              6
# 8   Blue October / Imogen Heap  Logged In    Kaylee      F              7
# 9                    Girl Talk  Logged In    Kaylee      F              8
# 10             Black Eyed Peas  Logged In    Sylvie      F              0
# 11                        None  Logged In      Ryan      M              0
# ...

# %%
for i in range(5):
    print(log_files[i])
# Out:
# C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A\A\A\TRAAAAW128F429D538.json
# C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A\A\A\TRAAABD128F429CF47.json
# C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A\A\A\TRAAADZ128F9348C2E.json
# C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A\A\A\TRAAAEF128F4273421.json
# C:\Users\Sachi\data-modeling-with-postgres-master\data\song_data\A\A\A\TRAAAFD128F92F423A.json

# %%
log_files = get_all_json_files_path(os.path.abspath("data/log_data/"))
for file in log_files:
    df = pd.read_json(file,lines = True)
    user_data = df[["userId","firstName","lastName","gender","level"]].values.tolist()
    print(user_data)
# Out:
# [[39, 'Walter', 'Frye', 'M', 'free'], [8, 'Kaylee', 'Summers', 'F', 'free'], [8, 'Kaylee', 'Summers', 'F', 'free'], [8, 'Kaylee', 'Summers', 'F', 'free'], [8, 'Kaylee', 'Summers', 'F', 'free'], [8, 'Kaylee', 'Summers', 'F', 'free'], [8, 'Kaylee', 'Summers', 'F', 'free'], [8, 'Kaylee', 'Summers', 'F', 'free'], [8, 'Kaylee', 'Summers', 'F', 'free'], [8, 'Kaylee', 'Summers', 'F', 'free'], [10, 'Sylvie', 'Cruz', 'F', 'free'], [26, 'Ryan', 'Smith', 'M', 'free'], [26, 'Ryan', 'Smith', 'M', 'free'], [26, 'Ryan', 'Smith', 'M', 'free'], [101, 'Jayden', 'Fox', 'M', 'free']]
# ...

# %%
from sql_queries import *

# %%
cur.execute(CREATE_USER_DATA_TABLE)

# %%
# for i in user_data:
cur.executemany(INSERT_INTO_USER_TABLE,user_data)

# %%
for file in log_files:
    df = pd.read_json(file,lines = True)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5c0d6540218e> in <module>
# ----> 1 for file in log_files:
#       2     df = pd.read_json(file,lines = True)
#       3 print(df)
#
# NameError: name 'log_files' is not defined

# %%
cur.execute(CREATE_SESSION_TIME_TABLE)

# %%
temp_df=df[df["page"]=="NextSong"].copy()

temp_df["ts"]=pd.to_datetime(temp_df["ts"],unit="ms")

time_df_values = (temp_df.ts, temp_df.ts.dt.hour , temp_df.ts.dt.day , temp_df.ts.dt.dayofweek , temp_df.ts.dt.month , temp_df.ts.dt.year , temp_df.ts.dt.weekday)
column_labels = ['start_time', 'hour', 'day', 'week', 'month', 'year', 'weekday']

time_df = pd.DataFrame.from_dict(dict(zip(column_labels, time_df_values)))

time_data=time_df.values.tolist()

cur.executemany(INSERT_INTO_SESSION_TABLE,time_data)
